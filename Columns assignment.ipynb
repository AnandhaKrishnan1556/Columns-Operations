# %%
import pandas as pd
import matplotlib.pyplot as mat
import seaborn as sea

# %% [markdown]
# #### Importing the libraries pandas ,matplotlib.pyplot an seaborn from python, in order to perform column operations on the dataset.

# %%
market=pd.read_csv("C:/Users/anand/OneDrive/Desktop/super_market.csv")

# %%
market
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
market.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# #### Displaying the variable names in the dataset.

# %%
market['total']=market['Unit price']+market['Quantity']

# %% [markdown]
# #### Added a new variable in the dataset by combining the variables Unit price and Quantity.

# %%
market
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
market['low']=market ['Unit price']/market['Quantity']

# %%
market
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
market.rename(columns={'Unit price':'Quantity'})
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Quantity  Quantity   Tax 5%      Total  \
# 0         Health and beauty     74.69         7  26.1415   548.9715
# 1    Electronic accessories     15.28         5   3.8200    80.2200
# 2        Home and lifestyle     46.33         7  16.2155   340.5255
# ...

# %% [markdown]
# #### Renamed a 'Unit Price' variable as 'Quantity '

# %%
market.rename(columns={'Payment':'Payment method','Total':'Final'})
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Final  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# #### Renamed Two variables 'Payment' as 'Payment method' and 'Total' as 'Final'

# %%
market.drop(['Tax 5%','Time'],axis=1)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity      Total       Date  \
# 0         Health and beauty       74.69         7   548.9715   1/5/2019
# 1    Electronic accessories       15.28         5    80.2200   3/8/2019
# ...

# %% [markdown]
# #### We have dropped the variables 'Tax 5%' and 'Time' from the dataset.

# %%
market.columns=[col.upper()for col in market.columns]

# %%
market
# Out:
#       INVOICE ID BRANCH       CITY CUSTOMER TYPE  GENDER  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                PRODUCT LINE  UNIT PRICE  QUANTITY   TAX 5%      TOTAL  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# #### Displayed the Variables name of the dataset in the Uppercase,

# %%
market.columns=[col.lower()for col in market.columns]

# %%
market
# Out:
#       invoice id branch       city customer type  gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                product line  unit price  quantity   tax 5%      total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# #### Displayed the Variables name of the dataset in the lowercase.

# %%
market.sort_values(by=['unit price','quantity'],ascending=[True,False])
# Out:
#       invoice id branch       city customer type  gender         product line  \
# 944  333-23-2632      A     Yangon        Member    Male    Health and beauty
# 572  239-48-4278      A     Yangon        Member    Male   Food and beverages
# 784  516-77-6464      C  Naypyitaw        Member  Female    Health and beauty
# 822  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
# 881  115-38-7388      C  Naypyitaw        Member  Female  Fashion accessories
# ..           ...    ...        ...           ...     ...                  ...
# 283  667-92-0055      A     Yangon        Member    Male    Health and beauty
# 494  437-53-3084      B   Mandalay        Normal    Male  Fashion accessories
# 930  641-62-7288      B   Mandalay        Normal    Male   Home and lifestyle
# 122  219-22-9386      B   Mandalay        Member    Male    Sports and travel
# 983  148-41-7930      C  Naypyitaw        Normal    Male    Health and beauty
#
# ...

# %% [markdown]
# #### In this we have sorted two variables 'unit price' and 'quantity' and then we have arranged the variable 'Unit Price' in the ascending order.

# %%
market.sort_values(by='quantity',ascending=True)
# Out:
#       invoice id branch       city customer type  gender         product line  \
# 321  622-20-1945      C  Naypyitaw        Normal  Female    Health and beauty
# 947  676-10-2200      B   Mandalay        Member    Male  Fashion accessories
# 415  268-03-6164      B   Mandalay        Normal    Male    Health and beauty
# 417  186-09-3669      C  Naypyitaw        Member  Female    Health and beauty
# 88   504-35-8843      A     Yangon        Normal    Male    Sports and travel
# ..           ...    ...        ...           ...     ...                  ...
# 182  851-28-6367      A     Yangon        Member    Male    Sports and travel
# 491  510-09-5628      A     Yangon        Member  Female  Fashion accessories
# 493  148-82-2527      C  Naypyitaw        Member  Female   Home and lifestyle
# 207  263-87-5680      C  Naypyitaw        Member  Female   Home and lifestyle
# 882  311-13-6971      B   Mandalay        Member    Male    Sports and travel
#
# ...

# %% [markdown]
# #### Sorted the variable named 'quantity' and arranged its values in ascending order.

# %%
market.sort_values(by='date')
# Out:
#       invoice id branch       city customer type  gender  \
# 496  556-97-7101      C  Naypyitaw        Normal  Female
# 484  493-65-6248      C  Naypyitaw        Member  Female
# 567  651-88-7328      A     Yangon        Normal  Female
# 523  133-14-7229      C  Naypyitaw        Normal    Male
# 970  746-04-1077      B   Mandalay        Member  Female
# ..           ...    ...        ...           ...     ...
# 393  308-47-4913      A     Yangon        Member  Female
# 73   841-35-6630      C  Naypyitaw        Normal  Female
# 433  616-87-0016      B   Mandalay        Normal    Male
# 585  127-47-6963      A     Yangon        Normal    Male
# 84   360-39-5055      C  Naypyitaw        Member    Male
#
#                product line  unit price  quantity   tax 5%     total  \
# 496  Electronic accessories       63.22         2   6.3220  132.7620
# 484       Sports and travel       36.98        10  18.4900  388.2900
# 567     Fashion accessories       65.74         9  29.5830  621.2430
# ...

# %% [markdown]
# #### We have sorted the variable named 'date'.

# %%
market.drop(['low'],axis=1,inplace=True)

# %%
market
# Out:
#       invoice id branch       city customer type  gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                product line  unit price  quantity   tax 5%      total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# #### We have dropped the variable named 'low' and used inplace function

# %%
market.groupby('unit price').count()
# Out:
#             invoice id  branch  city  customer type  gender  product line  \
# unit price
# 10.08                1       1     1              1       1             1
# 10.13                1       1     1              1       1             1
# 10.16                1       1     1              1       1             1
# 10.17                1       1     1              1       1             1
# 10.18                1       1     1              1       1             1
# ...                ...     ...   ...            ...     ...           ...
# 99.82                2       2     2              2       2             2
# 99.83                1       1     1              1       1             1
# 99.89                1       1     1              1       1             1
# 99.92                1       1     1              1       1             1
# 99.96                2       2     2              2       2             2
#
#             quantity  tax 5%  total  date  time  payment  cogs  \
# ...

# %% [markdown]
# #### By Performing groupby function on Unit Price variable and used count function it is displays us this variable takes place in 943 observations.

# %%
market=pd.read_csv("C:/Users/anand/OneDrive/Desktop/super_market.csv")

# %%
market
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
print(market['Unit price'].isnull().sum())
# Out:
# 0

# %% [markdown]
# #### We  found out that there is no null values present in the 'Unit Price'' variable.¶

# %%
print(market.columns.values)
# Out:
# ['Invoice ID' 'Branch' 'City' 'Customer type' 'Gender' 'Product line'
#  'Unit price' 'Quantity' 'Tax 5%' 'Total' 'Date' 'Time' 'Payment' 'cogs'
#  'gross margin percentage' 'gross income' 'Rating']

# %% [markdown]
# #### Displayed the variables but by using print function.
